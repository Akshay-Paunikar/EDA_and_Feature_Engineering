# %% [markdown]
# ### EDA & Feature Engineering on Zomato Dataset

# %%
# import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# read the dataset
df = pd.read_csv("E:\iNeuron\EDA_and_Feature_Engineering\Day_1_Zomato_Dataset\Zomatodataset\zomato.csv", encoding='latin-1')

# check first 5 records
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# check name of the columns
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# check dimensions of the dataset
df.shape
# Out:
# (9551, 21)

# %%
# check datatypes present
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
# descriptive statistics
df.describe(include='all').transpose()
# Out:
#                        count unique                         top  freq  \
# Restaurant ID         9551.0    NaN                         NaN   NaN
# Restaurant Name         9551   7446             Cafe Coffee Day    83
# Country Code          9551.0    NaN                         NaN   NaN
# City                    9551    141                   New Delhi  5473
# Address                 9551   8918  Dilli Haat, INA, New Delhi    11
# Locality                9551   1208             Connaught Place   122
# Locality Verbose        9551   1265  Connaught Place, New Delhi   122
# Longitude             9551.0    NaN                         NaN   NaN
# Latitude              9551.0    NaN                         NaN   NaN
# Cuisines                9542   1825                North Indian   936
# Average Cost for two  9551.0    NaN                         NaN   NaN
# Currency                9551     12          Indian Rupees(Rs.)  8652
# ...

# %%
# concise information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# #### In data analysis what all things we do:
#  - Check for missing/incorrect data or quality issues.
#  - Explore numerical variables.
#  - Explore categorical variables.
#  - Find relationships between features.

# %%
# check for missing values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# another way
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
# using a heatmap
plt.figure(figsize=(10,9))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.show()

# %%
# read the country code dataset
df_country = pd.read_excel('E:\iNeuron\EDA_and_Feature_Engineering\Day_1_Zomato_Dataset\Zomatodataset\Country-Code.xlsx')

# check records
df_country.head(20)
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# check dimensions of the data
df_country.shape
# Out:
# (15, 2)

# %%
# check columns from previous dataset
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# combine the 2 dataframes
final_df = pd.merge(df, df_country, on='Country Code',how='left')

# check the records
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# check datatypes
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
# check dimensions
final_df.shape
# Out:
# (9551, 22)

# %%
# descriptive statistics
final_df.describe(include='all').transpose()
# Out:
#                        count unique                         top  freq  \
# Restaurant ID         9551.0    NaN                         NaN   NaN
# Restaurant Name         9551   7446             Cafe Coffee Day    83
# Country Code          9551.0    NaN                         NaN   NaN
# City                    9551    141                   New Delhi  5473
# Address                 9551   8918  Dilli Haat, INA, New Delhi    11
# Locality                9551   1208             Connaught Place   122
# Locality Verbose        9551   1265  Connaught Place, New Delhi   122
# Longitude             9551.0    NaN                         NaN   NaN
# Latitude              9551.0    NaN                         NaN   NaN
# Cuisines                9542   1825                North Indian   936
# Average Cost for two  9551.0    NaN                         NaN   NaN
# Currency                9551     12          Indian Rupees(Rs.)  8652
# ...

# %%
# concise summary of the dataset
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# check for missing values
final_df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
# check for duplicated records
final_df.duplicated().sum()
# Out:
# 0

# %%
# Find out the top 3 countries who are using the zomato app
final_df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
country_names = final_df['Country'].value_counts().index
country_values = final_df['Country'].value_counts().values

# %%
# create a pie chart showing top 3 countries
plt.figure(figsize=(6,6))
plt.pie(country_values[:3], labels=country_names[:3], autopct='%1.2f%%')
plt.title("Top 3 Countries using Zomato")
plt.show()

# %% [markdown]
# #### The top 3 countries that are using zomato are : India - 94.39%, United States - 4.73%, United Kingdom - 0.87%

# %%
# Create a separare data for ratings
ratings = final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# #### INSIGHTS from above table
#  - Rating below 2.5 --->>> "Poor"
#  - Rating between 2.5 - 3.4 --->>> "Average"
#  - Rating between 3.5 - 3.9 --->>> "Good"
#  - Rating between 4.0 - 4.4 --->>> "Very Good"
#  - Rating above 4.4 --->>> "Excellent"

# %%
# Let's visualize above data using barplot
plt.figure(figsize=(12, 4))
sns.barplot(x='Aggregate rating', y='Rating Count', hue='Rating color',data=ratings, 
            palette=['blue', 'red', 'orange', 'yellow', 'lightgreen', 'green'],dodge=False)
plt.xlabel("Rating")
plt.ylabel("Counts")
plt.title("Aggregate Rating Counts")
plt.show()

# %% [markdown]
# #### Maximum number of ratings are between 2.6 to 4.2

# %%
# Countplot for Ratings Color
plt.figure(figsize=(8, 4))
sns.barplot(x='Rating color',y='Rating Count', data=ratings, palette=['blue', 'red', 'orange', 'yellow', 'lightgreen', 'green'],
                estimator=np.sum,dodge=False, ci=None)
plt.xlabel("Rating Color")
plt.ylabel("Counts")
plt.title("Countplot for Ratings Color")
plt.show()

# %%
# Find the countries that given 0 ratings or not rated
zero_rated_country = final_df[final_df['Rating color']=='White'].groupby(['Country']).size().reset_index().rename(columns={0:"Counts"})
zero_rated_country
# Out:
#           Country  Counts
# 0          Brazil       5
# 1           India    2139
# 2  United Kingdom       1
# 3   United States       3

# %%
zero_rated_country.values[:,1]
# Out:
# array([5, 2139, 1, 3], dtype=object)

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x='Country',y='Counts', data=zero_rated_country, dodge=False, ci=None)
plt.xlabel("Country")
plt.ylabel("Counts")
plt.title("Countries who gave 0 ratings/not rated")
plt.show()
